# %%
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam
import matplotlib.pyplot as plt
import itertools
import torch
import csv
import pandas as pd
import os, sys

# %%
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(project_root)
from Model.Featureless import MainNetwork

# %%
def calc_freq(X, Y):
    X = X.float()
    Y = Y.float()
    unique_X, inverse_indices = torch.unique(X, dim=0, return_inverse=True)
    new_Y = torch.zeros_like(Y)
    for k in range(unique_X.shape[0]):
        mask = (inverse_indices == k)
        avg_y = torch.mean(Y[mask], dim=0)
        new_Y[mask] = avg_y
    return new_Y


def process_csv(path, size):
    offerset_tensors = []
    target_tensors = []

    with open(path, 'r') as file:
        reader = csv.reader(file)
        k = 0
        for row in reader:
            if k == 0:
                k += 1
                continue
            offer_tensor, t_tensor = parse_line(row, size)
            offerset_tensors.append(offer_tensor)
            target_tensors.append(t_tensor)
    offer_tensor = torch.stack(offerset_tensors)
    tar_tensor = torch.stack(target_tensors)
    freq_tensor = calc_freq(offer_tensor, tar_tensor)
    return offer_tensor, tar_tensor, freq_tensor

def log_likelihood(out, y, safe_log=0):
    ones_indices = y == 1
    probabilities = out[ones_indices]
    negative_log_probabilities = -torch.log(probabilities + safe_log)
    total_negative_log_prob = torch.sum(negative_log_probabilities)
    return total_negative_log_prob / y.shape[0]

def train_synthetic(loss_name, num_epochs, dep):
    input_dim = 4
    main_network = MainNetwork(input_dim, dep, input_dim, ['qua']*(dep-1))
    train_file_path = os.path.join(project_root, 'Data', 'hypothetical-4p-train.csv')
    test_file_path = os.path.join(project_root, 'Data', 'hypothetical-4p-test.csv')

    df_train = pd.read_csv(train_file_path)
    df_test = pd.read_csv(test_file_path)
    X_columns = [col for col in df_train.columns if col.startswith('X')]
    Y_columns = [col for col in df_train.columns if col.startswith('Y')]
    X_train = torch.tensor(df_train[X_columns].values, dtype=torch.float)
    Y_train = torch.tensor(df_train[Y_columns].values, dtype=torch.float)
    Y_train_freq = calc_freq(X_train, Y_train)
    X_test = torch.tensor(df_test[X_columns].values, dtype=torch.float)
    Y_test = torch.tensor(df_test[Y_columns].values, dtype=torch.float)
    Y_test_freq = calc_freq(X_test, Y_test)
    optimizer = Adam(main_network.parameters(), lr=0.01, weight_decay=0)

    in_loss = None
    if loss_name == 'NLL':
        L = log_likelihood
    else:
        L = nn.MSELoss()
    for epoch in range(num_epochs):
        output, _ = main_network(X_train)
        loss = L(output, Y_train)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        in_loss = loss.item()
        with torch.no_grad():
            freq_loss = L(output, Y_train_freq)
        if (epoch + 1) % 100 == 0:
            print(f'Epoch [{epoch + 1}/{num_epochs}], Original Loss: {loss.item() ** 0.5:.4f},'
                  f' Frequency Loss: {freq_loss.item() ** 0.5:.8f}')
    final_output, _ = main_network(X_test)
    model_path = os.path.join(project_root, 'Model', 'Depth2Model-hyp.pth')
    torch.save(main_network, model_path)
    return in_loss ** 0.5, freq_loss.item() ** 0.5,\
        L(final_output, Y_test).item() ** 0.5, L(final_output, Y_test_freq).item() ** 0.5




Loss_Name = 'MSE'
epochs = 20000
depth = 2

in_sample_RMSE, in_sample_RMSE_Freq, out_sample_RMSE, out_sample_RMSE_Freq = train_synthetic(Loss_Name, epochs, depth)
print('in_sample_RMSE, in_sample_RMSE_Freq, out_sample_RMSE, out_sample_RMSE_Freq')
print(in_sample_RMSE,  in_sample_RMSE_Freq, out_sample_RMSE, out_sample_RMSE_Freq)
# Out:
# Epoch [100/20000], Original Loss: 0.3343, Frequency Loss: 0.01341077
# Epoch [200/20000], Original Loss: 0.3341, Frequency Loss: 0.00374278
# Epoch [300/20000], Original Loss: 0.3341, Frequency Loss: 0.00223320
# Epoch [400/20000], Original Loss: 0.3341, Frequency Loss: 0.00187912
# Epoch [500/20000], Original Loss: 0.3341, Frequency Loss: 0.00166246
# Epoch [600/20000], Original Loss: 0.3341, Frequency Loss: 0.00151996
# Epoch [700/20000], Original Loss: 0.3341, Frequency Loss: 0.00142028
# Epoch [800/20000], Original Loss: 0.3341, Frequency Loss: 0.00134425
# Epoch [900/20000], Original Loss: 0.3341, Frequency Loss: 0.00128065
# Epoch [1000/20000], Original Loss: 0.3341, Frequency Loss: 0.00122336
# Epoch [1100/20000], Original Loss: 0.3341, Frequency Loss: 0.00116937
# Epoch [1200/20000], Original Loss: 0.3341, Frequency Loss: 0.00111741
# Epoch [1300/20000], Original Loss: 0.3341, Frequency Loss: 0.00106723
# Epoch [1400/20000], Original Loss: 0.3341, Frequency Loss: 0.00101900
# Epoch [1500/20000], Original Loss: 0.3341, Frequency Loss: 0.00097307
# Epoch [1600/20000], Original Loss: 0.3341, Frequency Loss: 0.00092982
# Epoch [1700/20000], Original Loss: 0.3341, Frequency Loss: 0.00088944
# Epoch [1800/20000], Original Loss: 0.3341, Frequency Loss: 0.00085200
# Epoch [1900/20000], Original Loss: 0.3341, Frequency Loss: 0.00081742
# Epoch [2000/20000], Original Loss: 0.3341, Frequency Loss: 0.00080127
# Epoch [2100/20000], Original Loss: 0.3341, Frequency Loss: 0.00075651
# Epoch [2200/20000], Original Loss: 0.3341, Frequency Loss: 0.00073026
# Epoch [2300/20000], Original Loss: 0.3341, Frequency Loss: 0.00071176
# Epoch [2400/20000], Original Loss: 0.3341, Frequency Loss: 0.00068610
# Epoch [2500/20000], Original Loss: 0.3341, Frequency Loss: 0.00068871
# Epoch [2600/20000], Original Loss: 0.3341, Frequency Loss: 0.00065155
# Epoch [2700/20000], Original Loss: 0.3341, Frequency Loss: 0.00430438
# Epoch [2800/20000], Original Loss: 0.3341, Frequency Loss: 0.00062602
# Epoch [2900/20000], Original Loss: 0.3341, Frequency Loss: 0.00061229
# Epoch [3000/20000], Original Loss: 0.3341, Frequency Loss: 0.00086884
# Epoch [3100/20000], Original Loss: 0.3341, Frequency Loss: 0.00059546
# Epoch [3200/20000], Original Loss: 0.3341, Frequency Loss: 0.00058500
# Epoch [3300/20000], Original Loss: 0.3341, Frequency Loss: 0.00160129
# Epoch [3400/20000], Original Loss: 0.3341, Frequency Loss: 0.00057265
# Epoch [3500/20000], Original Loss: 0.3341, Frequency Loss: 0.00056508
# Epoch [3600/20000], Original Loss: 0.3341, Frequency Loss: 0.00057796
# Epoch [3700/20000], Original Loss: 0.3341, Frequency Loss: 0.00055583
# Epoch [3800/20000], Original Loss: 0.3341, Frequency Loss: 0.00262661
# Epoch [3900/20000], Original Loss: 0.3341, Frequency Loss: 0.00055046
# Epoch [4000/20000], Original Loss: 0.3341, Frequency Loss: 0.00054407
# Epoch [4100/20000], Original Loss: 0.3341, Frequency Loss: 0.00158736
# Epoch [4200/20000], Original Loss: 0.3341, Frequency Loss: 0.00053989
# Epoch [4300/20000], Original Loss: 0.3341, Frequency Loss: 0.00053481
# Epoch [4400/20000], Original Loss: 0.3341, Frequency Loss: 0.00104274
# Epoch [4500/20000], Original Loss: 0.3341, Frequency Loss: 0.00053073
# Epoch [4600/20000], Original Loss: 0.3341, Frequency Loss: 0.00052710
# Epoch [4700/20000], Original Loss: 0.3341, Frequency Loss: 0.00053380
# Epoch [4800/20000], Original Loss: 0.3341, Frequency Loss: 0.00052337
# Epoch [4900/20000], Original Loss: 0.3341, Frequency Loss: 0.00052070
# Epoch [5000/20000], Original Loss: 0.3341, Frequency Loss: 0.00052423
# Epoch [5100/20000], Original Loss: 0.3341, Frequency Loss: 0.00051743
# Epoch [5200/20000], Original Loss: 0.3341, Frequency Loss: 0.00051482
# Epoch [5300/20000], Original Loss: 0.3341, Frequency Loss: 0.00053578
# Epoch [5400/20000], Original Loss: 0.3341, Frequency Loss: 0.00051163
# Epoch [5500/20000], Original Loss: 0.3341, Frequency Loss: 0.00310605
# Epoch [5600/20000], Original Loss: 0.3341, Frequency Loss: 0.00050953
# Epoch [5700/20000], Original Loss: 0.3341, Frequency Loss: 0.00050600
# Epoch [5800/20000], Original Loss: 0.3341, Frequency Loss: 0.00058647
# Epoch [5900/20000], Original Loss: 0.3341, Frequency Loss: 0.00050351
# Epoch [6000/20000], Original Loss: 0.3341, Frequency Loss: 0.00050075
# Epoch [6100/20000], Original Loss: 0.3341, Frequency Loss: 0.00064439
# Epoch [6200/20000], Original Loss: 0.3341, Frequency Loss: 0.00049817
# Epoch [6300/20000], Original Loss: 0.3341, Frequency Loss: 0.00049557
# Epoch [6400/20000], Original Loss: 0.3341, Frequency Loss: 0.00053372
# Epoch [6500/20000], Original Loss: 0.3341, Frequency Loss: 0.00049256
# Epoch [6600/20000], Original Loss: 0.3341, Frequency Loss: 0.00167680
# Epoch [6700/20000], Original Loss: 0.3341, Frequency Loss: 0.00049012
# Epoch [6800/20000], Original Loss: 0.3341, Frequency Loss: 0.00049152
# Epoch [6900/20000], Original Loss: 0.3341, Frequency Loss: 0.00064771
# Epoch [7000/20000], Original Loss: 0.3341, Frequency Loss: 0.00048993
# Epoch [7100/20000], Original Loss: 0.3341, Frequency Loss: 0.00332532
# Epoch [7200/20000], Original Loss: 0.3341, Frequency Loss: 0.00048110
# Epoch [7300/20000], Original Loss: 0.3341, Frequency Loss: 0.00048482
# Epoch [7400/20000], Original Loss: 0.3341, Frequency Loss: 0.00048103
# Epoch [7500/20000], Original Loss: 0.3341, Frequency Loss: 0.00050064
# Epoch [7600/20000], Original Loss: 0.3341, Frequency Loss: 0.00047295
# Epoch [7700/20000], Original Loss: 0.3341, Frequency Loss: 0.00047365
# Epoch [7800/20000], Original Loss: 0.3341, Frequency Loss: 0.00046924
# Epoch [7900/20000], Original Loss: 0.3341, Frequency Loss: 0.00053451
# Epoch [8000/20000], Original Loss: 0.3341, Frequency Loss: 0.00063678
# Epoch [8100/20000], Original Loss: 0.3341, Frequency Loss: 0.00046449
# Epoch [8200/20000], Original Loss: 0.3341, Frequency Loss: 0.00046194
# Epoch [8300/20000], Original Loss: 0.3341, Frequency Loss: 0.00046224
# Epoch [8400/20000], Original Loss: 0.3341, Frequency Loss: 0.00045788
# Epoch [8500/20000], Original Loss: 0.3341, Frequency Loss: 0.00058965
# Epoch [8600/20000], Original Loss: 0.3341, Frequency Loss: 0.00045433
# Epoch [8700/20000], Original Loss: 0.3341, Frequency Loss: 0.00385612
# Epoch [8800/20000], Original Loss: 0.3341, Frequency Loss: 0.00045070
# Epoch [8900/20000], Original Loss: 0.3341, Frequency Loss: 0.00044736
# Epoch [9000/20000], Original Loss: 0.3341, Frequency Loss: 0.00048361
# Epoch [9100/20000], Original Loss: 0.3341, Frequency Loss: 0.00044403
# Epoch [9200/20000], Original Loss: 0.3341, Frequency Loss: 0.00044168
# Epoch [9300/20000], Original Loss: 0.3341, Frequency Loss: 0.00044143
# Epoch [9400/20000], Original Loss: 0.3341, Frequency Loss: 0.00043862
# Epoch [9500/20000], Original Loss: 0.3341, Frequency Loss: 0.00043749
# Epoch [9600/20000], Original Loss: 0.3341, Frequency Loss: 0.00043285
# Epoch [9700/20000], Original Loss: 0.3341, Frequency Loss: 0.00064455
# Epoch [9800/20000], Original Loss: 0.3341, Frequency Loss: 0.00101481
# Epoch [9900/20000], Original Loss: 0.3341, Frequency Loss: 0.00048505
# Epoch [10000/20000], Original Loss: 0.3341, Frequency Loss: 0.00042427
# Epoch [10100/20000], Original Loss: 0.3341, Frequency Loss: 0.00042323
# Epoch [10200/20000], Original Loss: 0.3341, Frequency Loss: 0.00170811
# Epoch [10300/20000], Original Loss: 0.3341, Frequency Loss: 0.00102103
# Epoch [10400/20000], Original Loss: 0.3341, Frequency Loss: 0.00042758
# Epoch [10500/20000], Original Loss: 0.3341, Frequency Loss: 0.00041407
# Epoch [10600/20000], Original Loss: 0.3341, Frequency Loss: 0.00065083
# Epoch [10700/20000], Original Loss: 0.3341, Frequency Loss: 0.00040768
# Epoch [10800/20000], Original Loss: 0.3341, Frequency Loss: 0.00040856
# Epoch [10900/20000], Original Loss: 0.3341, Frequency Loss: 0.00065252
# Epoch [11000/20000], Original Loss: 0.3341, Frequency Loss: 0.00045638
# Epoch [11100/20000], Original Loss: 0.3341, Frequency Loss: 0.00056043
# Epoch [11200/20000], Original Loss: 0.3341, Frequency Loss: 0.00142942
# Epoch [11300/20000], Original Loss: 0.3341, Frequency Loss: 0.00039259
# Epoch [11400/20000], Original Loss: 0.3341, Frequency Loss: 0.00074641
# Epoch [11500/20000], Original Loss: 0.3341, Frequency Loss: 0.00038732
# Epoch [11600/20000], Original Loss: 0.3341, Frequency Loss: 0.00056188
# Epoch [11700/20000], Original Loss: 0.3341, Frequency Loss: 0.00038218
# Epoch [11800/20000], Original Loss: 0.3341, Frequency Loss: 0.00058541
# Epoch [11900/20000], Original Loss: 0.3341, Frequency Loss: 0.00037609
# Epoch [12000/20000], Original Loss: 0.3341, Frequency Loss: 0.00041930
# Epoch [12100/20000], Original Loss: 0.3341, Frequency Loss: 0.00073372
# Epoch [12200/20000], Original Loss: 0.3341, Frequency Loss: 0.00036962
# Epoch [12300/20000], Original Loss: 0.3341, Frequency Loss: 0.00061266
# Epoch [12400/20000], Original Loss: 0.3341, Frequency Loss: 0.00036394
# Epoch [12500/20000], Original Loss: 0.3341, Frequency Loss: 0.00040721
# Epoch [12600/20000], Original Loss: 0.3341, Frequency Loss: 0.00036643
# Epoch [12700/20000], Original Loss: 0.3341, Frequency Loss: 0.00035805
# Epoch [12800/20000], Original Loss: 0.3341, Frequency Loss: 0.00037480
# Epoch [12900/20000], Original Loss: 0.3341, Frequency Loss: 0.00044536
# Epoch [13000/20000], Original Loss: 0.3341, Frequency Loss: 0.00034981
# Epoch [13100/20000], Original Loss: 0.3341, Frequency Loss: 0.00169409
# Epoch [13200/20000], Original Loss: 0.3341, Frequency Loss: 0.00034292
# Epoch [13300/20000], Original Loss: 0.3341, Frequency Loss: 0.00039272
# Epoch [13400/20000], Original Loss: 0.3341, Frequency Loss: 0.00050652
# Epoch [13500/20000], Original Loss: 0.3341, Frequency Loss: 0.00071584
# Epoch [13600/20000], Original Loss: 0.3341, Frequency Loss: 0.00049940
# Epoch [13700/20000], Original Loss: 0.3341, Frequency Loss: 0.00041915
# Epoch [13800/20000], Original Loss: 0.3341, Frequency Loss: 0.00032928
# Epoch [13900/20000], Original Loss: 0.3341, Frequency Loss: 0.00082418
# Epoch [14000/20000], Original Loss: 0.3341, Frequency Loss: 0.00108292
# Epoch [14100/20000], Original Loss: 0.3341, Frequency Loss: 0.00099614
# Epoch [14200/20000], Original Loss: 0.3341, Frequency Loss: 0.00158996
# Epoch [14300/20000], Original Loss: 0.3341, Frequency Loss: 0.00035712
# Epoch [14400/20000], Original Loss: 0.3341, Frequency Loss: 0.00031632
# Epoch [14500/20000], Original Loss: 0.3341, Frequency Loss: 0.00030942
# Epoch [14600/20000], Original Loss: 0.3341, Frequency Loss: 0.00030755
# Epoch [14700/20000], Original Loss: 0.3341, Frequency Loss: 0.00030187
# Epoch [14800/20000], Original Loss: 0.3341, Frequency Loss: 0.00030128
# Epoch [14900/20000], Original Loss: 0.3341, Frequency Loss: 0.00146239
# Epoch [15000/20000], Original Loss: 0.3341, Frequency Loss: 0.00080557
# Epoch [15100/20000], Original Loss: 0.3341, Frequency Loss: 0.00067670
# Epoch [15200/20000], Original Loss: 0.3341, Frequency Loss: 0.00044383
# Epoch [15300/20000], Original Loss: 0.3341, Frequency Loss: 0.00028567
# Epoch [15400/20000], Original Loss: 0.3341, Frequency Loss: 0.00031206
# Epoch [15500/20000], Original Loss: 0.3341, Frequency Loss: 0.00027697
# Epoch [15600/20000], Original Loss: 0.3341, Frequency Loss: 0.00029882
# Epoch [15700/20000], Original Loss: 0.3341, Frequency Loss: 0.00180415
# Epoch [15800/20000], Original Loss: 0.3341, Frequency Loss: 0.00026918
# Epoch [15900/20000], Original Loss: 0.3341, Frequency Loss: 0.00044598
# Epoch [16000/20000], Original Loss: 0.3341, Frequency Loss: 0.00073189
# Epoch [16100/20000], Original Loss: 0.3341, Frequency Loss: 0.00075330
# Epoch [16200/20000], Original Loss: 0.3341, Frequency Loss: 0.00091852
# Epoch [16300/20000], Original Loss: 0.3341, Frequency Loss: 0.00025662
# Epoch [16400/20000], Original Loss: 0.3341, Frequency Loss: 0.00027704
# Epoch [16500/20000], Original Loss: 0.3341, Frequency Loss: 0.00111906
# Epoch [16600/20000], Original Loss: 0.3341, Frequency Loss: 0.00024381
# Epoch [16700/20000], Original Loss: 0.3341, Frequency Loss: 0.00024904
# Epoch [16800/20000], Original Loss: 0.3341, Frequency Loss: 0.00026159
# Epoch [16900/20000], Original Loss: 0.3341, Frequency Loss: 0.00023698
# Epoch [17000/20000], Original Loss: 0.3341, Frequency Loss: 0.00085159
# Epoch [17100/20000], Original Loss: 0.3341, Frequency Loss: 0.00023104
# Epoch [17200/20000], Original Loss: 0.3341, Frequency Loss: 0.00032200
# Epoch [17300/20000], Original Loss: 0.3341, Frequency Loss: 0.00051334
# Epoch [17400/20000], Original Loss: 0.3341, Frequency Loss: 0.00025818
# Epoch [17500/20000], Original Loss: 0.3341, Frequency Loss: 0.00022074
# Epoch [17600/20000], Original Loss: 0.3341, Frequency Loss: 0.00028094
# Epoch [17700/20000], Original Loss: 0.3341, Frequency Loss: 0.00021267
# Epoch [17800/20000], Original Loss: 0.3341, Frequency Loss: 0.00022872
# Epoch [17900/20000], Original Loss: 0.3341, Frequency Loss: 0.00021091
# Epoch [18000/20000], Original Loss: 0.3341, Frequency Loss: 0.00063672
# Epoch [18100/20000], Original Loss: 0.3341, Frequency Loss: 0.00146357
# Epoch [18200/20000], Original Loss: 0.3341, Frequency Loss: 0.00032772
# Epoch [18300/20000], Original Loss: 0.3341, Frequency Loss: 0.00093574
# Epoch [18400/20000], Original Loss: 0.3341, Frequency Loss: 0.00020057
# Epoch [18500/20000], Original Loss: 0.3341, Frequency Loss: 0.00032629
# Epoch [18600/20000], Original Loss: 0.3341, Frequency Loss: 0.00039854
# Epoch [18700/20000], Original Loss: 0.3341, Frequency Loss: 0.00172401
# Epoch [18800/20000], Original Loss: 0.3341, Frequency Loss: 0.00018417
# Epoch [18900/20000], Original Loss: 0.3341, Frequency Loss: 0.00021925
# Epoch [19000/20000], Original Loss: 0.3341, Frequency Loss: 0.00091718
# Epoch [19100/20000], Original Loss: 0.3341, Frequency Loss: 0.00082420
# Epoch [19200/20000], Original Loss: 0.3341, Frequency Loss: 0.00020965
# Epoch [19300/20000], Original Loss: 0.3341, Frequency Loss: 0.00017034
# Epoch [19400/20000], Original Loss: 0.3341, Frequency Loss: 0.00018120
# Epoch [19500/20000], Original Loss: 0.3341, Frequency Loss: 0.00018667
# Epoch [19600/20000], Original Loss: 0.3341, Frequency Loss: 0.00025904
# Epoch [19700/20000], Original Loss: 0.3341, Frequency Loss: 0.00113346
# Epoch [19800/20000], Original Loss: 0.3341, Frequency Loss: 0.00128437
# Epoch [19900/20000], Original Loss: 0.3341, Frequency Loss: 0.00063363
# Epoch [20000/20000], Original Loss: 0.3341, Frequency Loss: 0.00120904
# in_sample_RMSE, in_sample_RMSE_Freq, out_sample_RMSE, out_sample_RMSE_Freq
# 0.3340659125664945 0.0012090436757949458 0.33204289584212177 0.0268876695484909

# %%
import numpy as np
import torch
import itertools
import torch.nn as nn
import torch.nn.functional as F
import matplotlib.pyplot as plt



def create_evaluation_tensor(indices, order):
    all_subsets = []
    p_subsets = []
    S = []
    for r in range(1, order + 2):
        subsets = itertools.combinations(indices, r)
        for subset in subsets:
            tensor = torch.zeros(len(indices))
            tensor[list(subset)] = 1
            tensor = tensor.unsqueeze(0)
            all_subsets.append(tensor)
            p_subsets.append(subset)
            if r == order + 1:
                continue
            S.append(subset) #doesn't include the full set - why?
    concatenated_tensor = torch.cat(all_subsets, dim=0)
    return concatenated_tensor, p_subsets, S


def cal_halo(evaluation, subsets, S): # evaluations[subset, U_j]
    key_list = [','.join(str(x) for x in s) for s in S]
    empty_value_list = [{} for _ in S]
    halo_dict = dict(zip(key_list, empty_value_list))
    halo_dict[''] = {}
    for idx, i in enumerate(subsets):
        i = list(i) # bad - don't modify whilst being iterated
        if len(i) == 1:
            j = i[0]
            halo_dict[''][str(j)] = evaluation[j, j].item()
        else:
            for k in range(len(i)): # example with i = [0,1] # k = 0 and k = 1
                effective_set = i[:k] + i[k + 1:] # [] + [1] and [0] + []
                key = ','.join(str(x) for x in effective_set)
                effect = evaluation[idx, i[k]].item()
                for r in range(1, len(effective_set)):
                    minus_subsets = itertools.combinations(effective_set, r)
                    for sub_s in minus_subsets:
                        effect -= halo_dict[','.join(str(x) for x in sub_s)][str(i[k])]
                effect -= halo_dict[''][str(i[k])]
                halo_dict[key][str(i[k])] = effect
    return halo_dict


def normalize_effect(halo_dict):
    for effect_set in list(halo_dict.keys()):
        avg_effect = np.mean(list(halo_dict[effect_set].values))
        for influenced_item in list(halo_dict[effect_set].keys()):
            halo_dict[effect_set][influenced_item] -= avg_effect
    return halo_dict


def insert_number(numbers_str, new_num):
    numbers_list = list(map(int, numbers_str.split(',')))
    numbers_list.append(int(new_num))
    numbers_list.sort(reverse=False)
    return ','.join(map(str, numbers_list))


def cal_ratio_halo(competing_set, halo, order):
    ratio_halo_dict_key = [key for key in list(halo.keys()) if len(key.split(',')) < order]
    product_pair = itertools.combinations(competing_set, 2)
    product_pair = [_ for _ in product_pair]
    product_pair_string = [','.join(str(x) for x in pt) for pt in product_pair]
    empty_value_list = [dict(zip(product_pair_string, [None for _ in product_pair_string]))
                        for _ in ratio_halo_dict_key]
    ratio_halo_dict = dict(zip(ratio_halo_dict_key, empty_value_list))
    for es in list(ratio_halo_dict.keys()):
        es_list = es.split(',')
        if len(es_list) == order:
            print(es_list)
            continue
        if es == '':
            for pair, pair_name in zip(product_pair, product_pair_string):
                x, y = str(pair[0]), str(pair[1])
                ratio_halo_dict[es][pair_name] = (halo[''][x] + halo[y][x]) - (halo[''][y] + halo[x][y])
        else:
            for pair, pair_name in zip(product_pair, product_pair_string):
                x, y = str(pair[0]), str(pair[1])
                if x in es_list or y in es_list:
                    ratio_halo_dict[es][pair_name] = 0
                else:
                    extra_es_x, extra_es_y = insert_number(es, x), insert_number(es, y)
                    ratio_halo_dict[es][pair_name] = \
                        halo[es][x] - halo[es][y] + halo[extra_es_y][x] - halo[extra_es_x][y]
    return ratio_halo_dict, product_pair_string


def generate_halo_effect_matrix(p_halo_effect_dict, p_optsize, p_offer_set):
    halo_effect_matrix = np.zeros((p_optsize, len(list(p_halo_effect_dict.keys())) - 1))
    for row in p_offer_set:
        for col, kk in enumerate(list(p_halo_effect_dict.keys())):
            if kk == '':
                continue
            if str(row) not in p_halo_effect_dict[kk]:
                if len(kk) > 1:
                    halo_effect_matrix[row, col] = 0
                else:
                    halo_effect_matrix[row, col] = p_halo_effect_dict[''][str(row)]
                continue
            halo_effect_matrix[row, col] = p_halo_effect_dict[kk][str(row)]
    return halo_effect_matrix


def generate_r_halo_matrix(p_r_halo_effect_dict, p_pair_names):
    p_effect_names = list(p_r_halo_effect_dict.keys())
    halo_effect_matrix = np.zeros((len(p_pair_names), len(p_effect_names)))
    for row, pair in enumerate(p_pair_names):
        for col, kk in enumerate(p_effect_names):
            halo_effect_matrix[row, col] = p_r_halo_effect_dict[kk][pair]
    return halo_effect_matrix


def process_list(input_list):
    result = []
    for string in input_list:
        parts = string.split(',')
        processed_parts = []
        for part in parts:
            try:
                num = int(part)
                processed_parts.append(str(num + 1))
            except ValueError:
                processed_parts.append(part)
        if processed_parts:
            result.append(','.join(processed_parts))
    return result


model_path = os.path.join(project_root, 'Model', 'Depth2Model-hyp.pth')
model = torch.load(model_path, map_location='cpu', weights_only=False)
model.eval()
optsize = 4
offer_set = [opt for opt in range(optsize)] # same as list(range(optsize))
max_effect_order = 3
evaluation_input, _, __ = create_evaluation_tensor(offer_set, max_effect_order)
choice_prob, eva = model(evaluation_input)
print("model evaluations")
print("choice_prob", choice_prob)
print("eva", eva)

halo_effect_dict = cal_halo(eva, _, __) # don't use these names
halo_matrix = generate_halo_effect_matrix(halo_effect_dict, optsize, offer_set)
r_halo_dict, pair_names = cal_ratio_halo(offer_set, halo_effect_dict, max_effect_order)
r_halo_matrix = generate_r_halo_matrix(r_halo_dict, pair_names)

effect_name_halo = [','.join(str(letter) for letter in name) for name in __]
effect_name_halo_r = process_list(list(r_halo_dict.keys())[:-1] + ['$∅$'])
pair_names = process_list(pair_names)

plt.figure(figsize=(12, 8))
cmap = plt.cm.RdBu
cmap.set_under('white')
plt.imshow(r_halo_matrix, cmap=cmap, interpolation='nearest', aspect='auto')
plt.xticks(range(len(effect_name_halo_r)), effect_name_halo_r, rotation=75, fontsize=16)
plt.yticks(range(len(pair_names)), pair_names, fontsize=16)

plt.colorbar()
plt.xlabel('Effect Source Set (T)', fontsize=18)
plt.ylabel('Competing Product Pair (j, k)', fontsize=18)
# plt.title('Halo-Ratio Effect Visualization', fontsize=24)
plt.savefig('Halo-Ratio Effect Visualization.pdf', format='pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# model evaluations
# choice_prob tensor([[1.0000, 0.0000, 0.0000, 0.0000],
#         [0.0000, 1.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 1.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000, 1.0000],
#         [0.9781, 0.0219, 0.0000, 0.0000],
#         [0.5057, 0.0000, 0.4943, 0.0000],
#         [0.5076, 0.0000, 0.0000, 0.4924],
#         [0.0000, 0.5217, 0.4783, 0.0000],
#         [0.0000, 0.5171, 0.0000, 0.4829],
#         [0.0000, 0.0000, 0.8946, 0.1054],
#         [0.5036, 0.0077, 0.4887, 0.0000],
#         [0.4965, 0.0105, 0.0000, 0.4930],
#         [0.4763, 0.0000, 0.4692, 0.0546],
#         [0.0000, 0.4870, 0.4536, 0.0594],
#         [0.4739, 0.0097, 0.4634, 0.0530]], grad_fn=<SoftmaxBackward0>)
# eva tensor([[ 1.4403e-01,        -inf,        -inf,        -inf],
#         [       -inf, -3.6091e-01,        -inf,        -inf],
#         [       -inf,        -inf,  1.5858e-02,        -inf],
#         [       -inf,        -inf,        -inf, -5.8525e-01],
#         [ 3.5779e-01, -3.4403e+00,        -inf,        -inf],
#         [ 6.7118e-01,        -inf,  6.4833e-01,        -inf],
#         [ 3.5713e-01,        -inf,        -inf,  3.2661e-01],
#         [       -inf,  8.6318e-02, -5.4901e-04,        -inf],
#         [       -inf, -4.0731e-01,        -inf, -4.7585e-01],
#         [       -inf,        -inf,  4.1644e-01, -1.7224e+00],
#         [ 9.0685e-01, -3.2785e+00,  8.7677e-01,        -inf],
#         [ 5.6526e-01, -3.2941e+00,        -inf,  5.5819e-01],
#         [ 9.5122e-01,        -inf,  9.3622e-01, -1.2155e+00],
#         [       -inf,  4.6560e-01,  3.9438e-01, -1.6386e+00],
#         [ 1.1813e+00, -2.7066e+00,  1.1590e+00, -1.0095e+00]],
#        grad_fn=<MaskedFillBackward0>)
